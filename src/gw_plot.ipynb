# %% [markdown]
# <a href="https://colab.research.google.com/github/fxlpsz/astrophysics/blob/main/astro_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py

# %%
# Reading data file
fileName = '../data/H-H1_LOSC_4_V1-815411200-4096.hdf5'
dataFile = h5py.File(fileName, 'r')

# %%
# Catching some parameters
strain = dataFile['strain']['Strain'][()]
ts = dataFile['strain']['Strain'].attrs['Xspacing']
meta = dataFile['meta']

# %%
# Creating a time vector
gpsStart = meta['GPSstart'][()]
duration = meta['Duration'][()]
gpsEnd = gpsStart + duration

time = np.arange(gpsStart, gpsEnd, ts)
print(time)
# Out:
# [8.15411200e+08 8.15411200e+08 8.15411200e+08 ... 8.15415296e+08
#  8.15415296e+08 8.15415296e+08]

# %%
# Ploting the time series
numSamples = 10000

plt.plot(time[0:numSamples], strain[0:numSamples])
plt.xlabel('GPS Time (s)')
plt.ylabel('H1 Strain')
plt.show()
